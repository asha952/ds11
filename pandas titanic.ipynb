# %%
import numpy as np
import pandas as pd

df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
import matplotlib.pyplot as plt

df['Age'].hist(bins=16)
plt.show()

# %%
df['Age'].isna().sum() # number of empty age values
# Out:
# 177

# %%
# Make a new column with 0,1 mapped to female,male
df['Gender'] = df['Sex'].map( {'female': 0, 'male': 1} ).astype(int)

# %%
df['Age'].plot.box()

# %%
len(df['Age'].dropna()) # number of not-null values
# Out:
# 714

# %%
# Passengers embarked in section C
pd.set_option('display.max_rows', None)
df[df['Embarked'] == 'C']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# 31            32         1       1
# 34            35         0       1
# 36            37         1       3
# 39            40         1       3
# 42            43         0       3
# 43            44         1       2
# 48            49         0       3
# 52            53         1       1
# 54            55         0       1
# 57            58         0       3
# 60            61         0       3
# 64            65         0       1
# 65            66         1       3
# 73            74         0       3
# 96            97         0       1
# 97            98         1       1
# 111          112         0       3
# 114          115         0       3
# 118          119         0       1
# 122          123         0       2
# ...

# %%
# Number of passengers that embarked
len(df[df['Embarked'] == 'C'])
# Out:
# 168

# %%
pd.set_option('display.max_rows', 10)
df[df['Embarked'] == 'C'].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   168.000000  168.000000  168.000000  130.000000  168.000000
# mean    445.357143    0.553571    1.886905   30.814769    0.386905
# std     259.454201    0.498608    0.944100   15.434860    0.557213
# min       2.000000    0.000000    1.000000    0.420000    0.000000
# 25%     235.500000    0.000000    1.000000   21.250000    0.000000
# 50%     455.000000    1.000000    1.000000   29.000000    0.000000
# 75%     651.000000    1.000000    3.000000   40.000000    1.000000
# max     890.000000    1.000000    3.000000   71.000000    2.000000
#
#             Parch        Fare      Gender
# count  168.000000  168.000000  168.000000
# mean     0.363095   59.954144    0.565476
# std      0.660481   83.912994    0.497176
# min      0.000000    4.012500    0.000000
# 25%      0.000000   13.697950    0.000000
# 50%      0.000000   29.700000    1.000000
# 75%      1.000000   78.500025    1.000000
# ...

# %%
df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
df['Embarked'].value_counts().plot(kind='bar')

# %%
df['Embarked'].value_counts().plot(kind='barh').invert_yaxis()

# %%
import seaborn as sns


# Bar Chart Example #1 (Simple): Categorical Variables Showing Counts
sns.countplot(x="Embarked", palette="spring", data=df)

# %%
## Number of male and female passengers
sex_count = df['Sex'].dropna().value_counts()

# %%
sex_count
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.groupby('Sex').plot.scatter(x='Age', y='Fare')
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df[df['Embarked'] == 'C'].groupby('Sex').plot.scatter(x='Age', y='Fare')
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
sns.countplot(x='Sex', hue="Pclass", data=df[(df.Embarked=='C') & (df.Survived==1)])
